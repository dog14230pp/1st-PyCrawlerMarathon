# %% [markdown]
# # 反爬：代理伺服器/IP
#
# * 了解「IP 黑/白名單」的反爬蟲機制
# * 「IP 黑/白名單」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 目前程式中的 proxy_ips 是手動輸入的，請根據 https://free-proxy-list.net/ 寫一個可自動化抓取可用 Proxy 的 proxy_ips。

# %%
proxy_ips = []

import requests
from bs4 import BeautifulSoup
import random

r = requests.get('https://free-proxy-list.net/')
soup = BeautifulSoup(r.text, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width,initial-scale=1,maximum-scale=1" name="viewport"/><meta content="origin" name="referrer"/><link href="https://cdn.jsdelivr.net/bootstrap/3.3.7/css/bootstrap.min.css" rel="stylesheet"/><link href="https://cdn.datatables.net/1.10.15/css/dataTables.bootstrap.min.css" rel="stylesheet"/><link href="https://cdn.jsdelivr.net/fontawesome/4.5.0/css/font-awesome.min.css" rel="stylesheet"/><link href="https://free-proxy-list.net/css/fpl20123.css" rel="stylesheet"/><link href="https://fonts.googleapis.com/css?family=Montserrat:400,600" rel="stylesheet"/><link href="https://free-proxy-list.net/favicon.ico" rel="icon"/><meta content="Here are the latest 300 free proxies that are just checked and added into our proxy list. The proxy list is updated every 10 minutes to keep fresh." name="description"/><title>Free Proxy List - Just Checked Proxy List</title></head><body><script>(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# ga('create', 'UA-158616-8', 'auto');</script><nav class="navbar navbar-default navbar-fixed-top"><div class="container"><div class="navbar-header"><button class="navbar-toggle" data-target="#main-menu" data-toggle="collapse" type="button"><span class="icon-bar"></span> <span class="icon-bar"></span> <span class="icon-bar"></span></button> <a class="logo" href="https://free-proxy-list.net/">Free Proxy List</a></div><div class="collapse navbar-collapse" id="main-menu"><ul class="nav navbar-nav navbar-right" id="menu-main-menu"><li class="dropdown" id="tab_home"><a class="dropdown-toggle" data-toggle="dropdown" href="#">Free Proxy <b class="caret"></b></a><ul class="dropdown-menu"><li><a href="https://free-proxy-list.net/">New Proxy</a></li><li id="tab_us"><a href="https://www.us-proxy.org/">US Proxy</a></li><li><a href="https://free-proxy-list.net/uk-proxy.html">UK Proxy</a></li><li id="tab_ssl"><a href="https://www.sslproxies.org/">SSL Proxy</a></li><li><a href="https://free-proxy-list.net/anonymous-proxy.html">Anonymous Proxy</a></li><li><a href="http://www.google-proxy.net/">Google Proxy</a></li></ul></li><li class="dropdown" id="tab_web"><a class="dropdown-toggle" data-toggle="dropdown" href="#">Web Proxy <b class="caret"></b></a><ul class="dropdown-menu"><li><a href="https://proxysite.one" target="_blank">Proxy Site #1</a></li><li><a href="https://unblockyoutube.video" target="_blank">Unblock Youtube</a></li><li><a href="https://freeproxy.win" target="_blank">Free Proxy</a></li><li><a href="https://www.proxy-youtube.com" target="_blank">Proxy Youtube</a></li><li><a href="https://free-proxy-list.net/web-proxy.html">Web Proxies</a></li></ul></li><li id="tab_socks"><a href="https://www.socks-proxy.net/">Socks Proxy</a></li><li class="dropdown" id="tab_buy"><a class="dropdown-toggle" data-toggle="dropdown" href="#">Buy Proxy <b class="caret"></b></a><ul class="dropdown-menu"><li><a href="https://myiphide.com/" onclick="gaEvent('outbound', 'myiphide/navmenu', 'My IP Hide');" target="_blank">My IP Hide</a></li><li><a href="https://www.us-proxy.org/buyproxy.html" onclick="gaEvent('click', 'buyproxy/navmenu', 'Http Proxy');">Http Proxy</a></li><li><a href="https://www.socks-proxy.net/buysocksproxy.html" onclick="gaEvent('click', 'buysocks/navmenu', 'Socks Proxy');">Socks Proxy</a></li></ul></li><li class="dropdown"><a class="dropdown-toggle" data-toggle="dropdown" href="#">Company <b class="caret"></b></a><ul class="dropdown-menu"><li><a href="https://www.didsoft.com/" target="_blank">Didsoft</a></li><li><a href="https://www.didsoft.com/contact.html" target="_blank">Contact Us</a></li><li><a href="https://www.didsoft.com/product.html" target="_blank">Products</a></li></ul></li></ul></div></div></nav><header id="header"><div class="container"><div class="row"><div class="col-md-6"><div class="intro-text"><h2 class="intro-lead-in"><span class="fa-stack"><i class="fa fa-certificate fa-stack-2x" style="color:#f4aa0b"></i> <span class="fa-stack-1x header-new">NEW</span></span> My<span class="mihsp"> </span>IP<span class="mihsp"> </span>Hide is better than Free Proxy</h2><span class="intro-heading">Hide IP address and unblock websites with lightning fast, stable, and encrypted proxies.</span><div class="header-buttons"><a class="primary-button" href="https://myiphide.com/" onclick="gaEvent('click', 'myiphide/headerbtn', 'Learn More');" target="_blank">Learn More  <i class="fa fa-external-link"></i></a> <a class="secondary-button hidden-xs" href="#list" onclick="gaEvent('click', 'proxylist/headerbtn', 'Free Proxy');">Free Proxy</a></div></div></div><div class="col-md-6"><div class="header-dashboard"><img alt="My IP Hide" class="dashboard img-responsive" src="https://myiphide.com/images/multi-devices.png"/></div></div></div></div><div id="particles-js"></div></header><section id="list"><div class="container"><div class="text-center"><h1 class="section-heading">Free Proxy List</h1><span class="separator"></span><p class="section-subheading" ...
# function changebills(){
# if('m'==bill){
# bill='y';
# $('.mbill').hide();
# $('.ybill').show();
# $('#mlabel').removeClass('active');
# $('#ylabel').addClass('active');
# $("a[href^='https://my.didsoft.com/order/cart.php']")
# .each(function(){this.href += 'm12';});
# $('#3kd3').attr('href', 'https://my.didsoft.com/order/cart.php?pid=http3000d3');
# } else{
# bill = 'm';
# $('.ybill').hide();
# $('.mbill').show();
# $('#ylabel').removeClass('active');
# $('#mlabel').addClass('active');
# $("a[href^='https://my.didsoft.com/order/cart.php']")
# .each(function(){this.href = this.href.replace(/m12$/, "");});
# }
# }</script><section class="hidden-print" id="httpproxy"><div class="container"><div class="row"><div class="col-lg-12 text-center"><h2 class="section-heading">Buy Proxy</h2><span class="separator"></span><p class="section-subheading">Thousands of HTTP(S) proxies for SEO or traffic tools</p></div></div><div class="row"><div class="col-md-5"><img alt="Download Proxy List" class="img-responsive img-unblock" src="images/gethttpproxy.png"/></div><div class="col-md-7"><ul class="big-ul"><li>Our proxy list service supports <b>all systems</b>, including Windows, Mac, Linux, Android, and iOS.</li><li>You can use our <a href="#get"><b>API URL</b></a> to get the proxy list on all systems.</li><li>Windows users can use our <a href="#get"><b>free App</b></a> to get and test the HTTP proxy lists.</li><li>You can custom the output <b>format</b> of the proxy list using our API.</li><li>Our proxy lists are updated every <b>30 minutes</b>.</li><li>Using the API, you can show the <b>country</b> information of the proxies and <b>filter</b> them by country.</li><li>You can choose to get the <b>HTTPS/SSL</b> proxies only.</li></ul><div class="btn-ul"><a class="btn-blue" href="#get" onclick="gaEvent('click', 'get/paidhttp', 'Get HTTP Proxy List');">Get HTTP Proxy List <i class="fa fa-angle-double-down"></i></a></div></div></div></div></section><section class="gray-bg hidden-print" id="get"><div class="container"><div class="row"><div class="col-lg-12 text-center"><h2 class="section-heading">Get Proxy</h2><span class="separator"></span><p class="section-subheading">Get our proxy list by our free program or API URL</p></div></div><div class="row"><div class="col-md-6 col-md-push-6 text-center pure-text"><p class="hidden-sm hidden-xs"><img alt="Get Proxy List by API URL" class="img-responsive img-api" src="images/apihttp.png"/></p><p><b>Get Proxy List by API URL (All System)</b></p><p>The API is just a link. You can open the <a href="https://www.my-proxy.com/blog/get-proxy-list-using-api" target="_blank">API link</a> in the browser or your own script/program to get the proxy list.</p><p class="hidden-md hidden-lg"><img alt="Get Proxy List by API URL" class="img-responsive img-api" src="images/apihttp.png"/></p></div><div class="col-md-6 col-md-pull-6 text-center pure-text"><p class="hidden-sm hidden-xs"><img alt="Download Proxy List by Program" class="img-responsive img-app" src="images/httplist.png"/></p><p><b>Get Proxy List by Our Free Program (Windows)</b></p><p>First, download and run our free program <a href="https://www.eliteproxyswitcher.com/EPS_setup.exe" target="_blank">Elite Proxy Switcher</a>. Then click its menu <b>File</b> &gt; <b>Download list</b> to get the list.</p><p class="hidden-md hidden-lg"><img alt="Download Proxy List by Program" class="img-responsive img-app" src="images/httplist.png"/></p></div></div><div class="row"><div class="col-lg-12 text-center top-margin"><a class="btn-blue" href="#pricing" onclick="gaEvent('click', 'httppricing/get', 'Buy HTTP Proxy List');">Buy HTTP Proxy List <i class="fa fa-angle-double-down"></i></a><div class="mb30-left">15-day money-back guarantee</div></div></div></div></section><section class="hidden-print" id="pricing"><div class="container"><div class="row"><div class="col-lg-12 text-center"><h2 class="section-heading">Buy Proxy</h2><span class="separator"></span><p class="section-subheading">100% 15-day money-back guarantee. Cancel at any time.</p><p class="billing"><span class="term active" id="mlabel">Monthly Billing</span> or <span class="term" id="ylabel">Yearly Billing</span> <span class="label">2 Months Free</span></p></div></div><div class="row outer-margin"><div class="col-md-4"><div class="row pricing-title">HTTP 6500</div><div class="row pricing"><div class="col-lg-3 col-md-3 col-sm-3"><div class="row"><span class="pricing-price"><span class="currency">$</span><span class="mbill">59.95</span><span class="ybill">599.5</span></span><div class="billing-time">per <span class="mbill">mont ...

# %%
for tmp in soup.find('tbody').find_all('tr'):
    proxy_ips.append(tmp.find('td').text)
proxy_ips
# Out:
# ['43.229.95.244',
#  '159.224.220.63',
#  '1.10.188.42',
#  '177.94.206.67',
#  '46.246.14.6',
#  '200.8.223.161',
#  '80.87.184.49',
#  '190.242.41.133',
#  '78.41.174.197',
#  '62.152.75.110',
#  '200.149.214.6',
#  '124.41.213.44',
#  '177.37.240.52',
#  '178.150.97.102',
#  '149.56.148.219',
#  '138.122.140.35',
#  '5.9.218.106',
#  '46.235.71.241',
#  '103.142.69.130',
#  '91.191.250.142',
#  '31.192.140.211',
#  '154.211.13.171',
#  '41.217.219.49',
#  '36.66.61.155',
#  '194.135.75.74',
#  '95.170.208.42',
#  '173.46.67.172',
#  '92.84.56.10',
#  '177.130.63.245',
#  '103.130.114.122',
#  '185.54.237.114',
#  '185.34.22.225',
#  '85.10.219.100',
#  '82.137.250.145',
#  '118.173.233.31',
#  '200.89.159.240',
#  '50.236.148.246',
#  '85.10.219.97',
#  '61.19.40.50',
#  '186.42.175.138',
#  '182.93.85.222',
#  '196.3.97.34',
#  '115.126.167.71',
#  '148.251.200.199',
#  '1.179.148.9',
#  '185.99.64.75',
#  '85.132.66.210',
#  '200.223.86.174',
#  '109.199.77.83',
#  '5.9.218.107',
#  '23.244.28.27',
#  '91.241.21.155',
#  '91.192.4.162',
#  '47.89.193.30',
#  '134.209.184.20',
#  '103.68.18.118',
#  '110.5.100.130',
#  '68.183.45.111',
#  '176.241.137.95',
#  '95.104.54.227',
#  '181.113.135.254',
#  '103.102.139.186',
#  '36.92.55.50',
#  '91.187.75.48',
#  '91.219.56.221',
#  '58.96.150.62',
#  '1.20.101.149',
#  '61.9.82.34',
#  '84.53.247.204',
#  '134.19.254.2',
#  '157.119.207.10',
#  '75.146.218.153',
#  '109.74.142.138',
#  '181.57.198.102',
#  '103.133.204.169',
#  '167.172.188.130',
#  '157.119.207.36',
#  '124.122.100.233',
#  '41.75.123.49',
#  '158.140.167.148',
#  '87.251.238.156',
#  '36.75.212.60',
#  '162.249.248.218',
#  '5.160.72.148',
#  '165.16.3.153',
#  '102.176.160.70',
#  '78.38.111.252',
#  '170.0.48.38',
#  '37.255.134.142',
#  '200.186.53.98',
#  '91.192.2.168',
#  '185.134.23.171',
#  '124.219.176.139',
#  '158.255.23.146',
#  '103.216.82.37',
#  '182.52.30.162',
#  '160.119.131.114',
#  '138.97.12.150',
#  '94.205.140.158',
#  '212.28.237.133',
#  '36.67.246.50',
#  '202.169.37.126',
#  '36.66.175.111',
#  '93.87.17.1',
#  '200.236.221.242',
#  '116.254.100.165',
#  '139.59.81.245',
#  '36.89.27.235',
#  '41.170.12.92',
#  '167.71.87.213',
#  '36.89.227.98',
#  '124.121.2.57',
#  '177.42.178.146',
#  '5.172.188.93',
#  '202.9.122.224',
#  '193.29.59.122',
#  '95.47.234.1',
#  '1.0.135.155',
#  '181.191.180.110',
#  '189.90.254.147',
#  '34.220.237.17',
#  '5.138.20.232',
#  '187.109.181.77',
#  '14.207.138.177',
#  '177.131.22.186',
#  '101.109.11.26',
#  '202.142.155.146',
#  '177.126.93.170',
#  '45.183.143.30',
#  '138.117.37.244',
#  '179.176.15.8',
#  '36.78.184.209',
#  '41.50.85.241',
#  '36.74.54.228',
#  '192.141.5.59',
#  '177.106.254.78',
#  '114.29.236.225',
#  '203.202.248.36',
#  '94.41.43.98',
#  '146.88.36.71',
#  '165.22.250.149',
#  '119.42.97.160',
#  '36.74.47.4',
#  '177.38.139.223',
#  '128.199.90.230',
#  '176.98.76.203',
#  '187.44.167.78',
#  '91.203.224.177',
#  '45.234.200.18',
#  '41.169.146.2',
#  '45.70.208.42',
#  '45.235.87.65',
#  '118.97.235.234',
#  '64.17.30.238',
#  '147.78.160.10',
#  '45.71.80.2',
#  '202.162.201.94',
#  '24.172.34.114',
#  '91.207.61.241',
#  '154.127.120.18',
#  '186.46.136.70',
#  '195.209.131.19',
#  '138.68.53.44',
#  '118.69.61.212',
#  '103.217.78.5',
#  '3.130.206.234',
#  '187.188.213.4',
#  '186.46.6.233',
#  '106.104.151.142',
#  '139.5.71.126',
#  '81.24.85.120',
#  '124.158.177.171',
#  '191.103.219.225',
#  '14.98.195.90',
#  '182.53.197.202',
#  '103.25.167.200',
#  '101.109.255.97',
#  '110.74.195.215',
#  '195.182.22.178',
#  '36.89.187.193',
#  '95.78.174.219',
#  '110.74.222.106',
#  '177.46.147.89',
#  '36.92.185.49',
#  '115.127.114.76',
#  '79.104.25.218',
#  '213.6.38.50',
#  '186.226.183.170',
#  '85.223.157.204',
#  '103.78.213.226',
#  '182.52.90.42',
#  '200.85.169.18',
#  '103.126.149.98',
#  '194.35.115.4',
#  '103.93.233.14',
#  '80.59.199.212',
#  '91.206.148.243',
#  '189.14.193.242']

# %%
for i in range(300):
    ip = random.choice(proxy_ips)
    print('Use', ip)
    try:
        resp = requests.get('http://ip.filefab.com/index.php',
                        proxies={'http': ip, 'https': ip}, timeout=10)
        soup = BeautifulSoup(resp.text, 'html5lib')
        print(soup.find('h1', id='ipd').text.strip())
    except:
        print('Fail')
# Out:
# Use 109.199.77.83
# Fail
# Use 177.106.254.78
# Fail
# Use 191.34.122.233
# Fail
# Use 110.74.195.215
# Fail
# Use 95.80.252.189
# Fail
# Use 5.160.72.148
# Fail
# Use 212.28.237.133
# Fail
# Use 80.87.184.49
# Fail
# Use 71.183.100.116
# Your IP address: 71.183.100.116
# Use 41.50.85.241
# Fail
# Use 202.169.37.126
# Fail
# Use 186.46.6.233
# Fail
# Use 1.2.169.12
# Fail
# Use 91.135.148.198
# Fail
# Use 124.122.100.233
# Fail
# Use 200.149.214.6
# Fail
# Use 95.80.252.189
# Fail
# Use 36.67.246.50
# Fail
# Use 34.220.237.17
# Fail
# Use 138.117.37.244
# Fail
# Use 41.217.219.49
# Fail
# Use 43.229.95.244
# Fail
# Use 124.121.2.57
# Fail
# Use 66.96.193.206
# Fail
# Use 95.170.208.42
# Fail
# Use 31.41.92.154
# Fail
# Use 41.217.219.49
# Fail
# Use 1.20.97.122
# Fail
# Use 187.188.213.4
# Fail
# Use 190.52.193.97
# Fail
# Use 165.16.3.153
# Fail
# Use 177.37.240.52
# Fail
# Use 87.251.238.156
# Fail
# Use 189.90.254.147
# Fail
# Use 138.97.12.150
# Fail
# Use 176.119.134.176
# Fail
# Use 139.59.215.181
# Fail
# Use 85.132.66.210
# Fail
# Use 114.5.195.226
# Fail
# Use 170.0.48.38
# Fail
# Use 195.182.22.178
# Fail
# Use 200.174.158.26
# Fail
# Use 87.251.238.156
# Fail
# Use 79.115.245.227
# Fail
# Use 200.89.159.240
# Fail
# Use 36.74.47.4
# Your IP address: 36.74.47.4
# Use 5.9.218.106
# Fail
# Use 91.206.148.243
# Fail
# Use 190.147.137.66
# Fail
# Use 36.74.54.228
# Your IP address: 36.74.54.228
# Use 61.9.82.34
# Fail
# Use 47.89.193.30
# Fail
# Use 115.126.167.71
# Fail
# Use 193.29.59.122
# Fail
# Use 36.89.187.193
# Fail
# Use 103.216.82.37
# Fail
# Use 115.127.114.76
# Fail
# Use 103.250.152.22
# Fail
# Use 64.17.30.238
# Fail
# Use 50.236.148.246
# Fail
# Use 91.192.2.168
# Fail
# Use 134.209.184.20
# Fail
# Use 195.209.131.19
# Fail
# Use 94.232.126.225
# Fail
# Use 34.220.237.17
# Fail
# Use 36.37.73.245
# Fail
# Use 71.183.100.116
# Your IP address: 71.183.100.116
# Use 81.24.85.120
# Fail
# Use 181.191.180.110
# Fail
# Use 188.235.8.5
# Fail
# Use 176.119.134.176
# Fail
# Use 24.172.34.114
# Fail
# Use 195.182.22.178
# Fail
# Use 92.84.56.10
# Fail
# Use 5.138.20.232
# Fail
# Use 103.133.204.169
# Fail
# Use 79.115.245.227
# Fail
# Use 95.104.54.227
# Fail
# Use 91.203.224.177
# Fail
# Use 191.98.184.122
# Fail
# Use 103.142.69.130
# Fail
# Use 110.5.100.130
# Fail
# Use 61.19.40.50
# Fail
# Use 146.88.36.71
# Fail
# Use 110.74.195.215
# Fail
# Use 91.135.148.198
# Fail
# Use 94.205.140.158
# Fail
# Use 77.56.156.148
# Fail
# Use 177.130.63.245
# Fail
# Use 138.122.140.35
# Fail
# Use 31.28.99.25
# Fail
# Use 116.254.100.165
# Fail
# Use 103.250.152.22
# Fail
# Use 41.75.123.49
# Fail
# Use 103.133.204.169
# Fail
# Use 138.68.53.44
# Fail
# Use 109.74.142.138
# Fail
# Use 45.183.143.30
# Fail
# Use 177.130.63.245
# Fail
# Use 103.142.69.130
# Fail
# Use 103.25.167.200
# Fail
# Use 118.173.233.31
# Fail
# Use 1.20.101.149
# Fail
# Use 36.89.27.235
# Fail
# Use 200.85.169.18
# Fail
# Use 36.89.187.193
# Fail
# Use 177.128.42.25
# Fail
# Use 37.57.15.43
# Fail
# Use 195.182.22.178
# Fail
# Use 114.29.236.225
# Fail
# Use 91.135.194.22
# Fail
# Use 138.68.53.44
# Fail
# Use 142.93.122.175
# Fail
# Use 37.57.15.43
# Fail
# Use 177.130.63.245
# Fail
# Use 139.5.71.126
# Fail
# Use 212.28.237.133
# Fail
# Use 146.88.36.71
# Fail
# Use 5.160.72.148
# Fail
# Use 103.142.69.130
# Fail
# Use 1.179.148.9
# Fail
# Use 103.68.18.118
# Fail
# Use 1.20.97.122
# Fail
# Use 91.207.61.241
# Fail
# Use 95.216.120.27
# Fail
# Use 182.52.51.53
# Fail
# Use 85.234.126.107
# Fail
# Use 103.216.82.44
# Fail
# Use 200.236.221.242
# Fail
# Use 36.67.246.50
# Fail
# Use 118.173.233.80
# Fail
# Use 95.216.120.27
# Fail
# Use 185.34.22.225
# Fail
# Use 185.34.22.225
# Fail
# Use 193.29.59.122
# Fail
# Use 110.74.195.215
# Fail
# Use 36.37.73.245
# Fail
# Use 45.70.208.42
# Fail
# Use 182.53.197.87
# Fail
# Use 177.126.93.170
# Fail
# Use 78.41.174.197
# Fail
# Use 186.42.175.138
# Fail
# Use 195.209.131.19
# Fail
# Use 58.96.150.62
# Fail
# Use 45.112.57.110
# Fail
# Use 119.42.97.160
# Fail
# Use 36.89.27.235
# Fail
# Use 170.247.152.163
# Fail
# Use 189.14.193.242
# Fail
# Use 36.74.47.4
# Your IP address: 36.74.47.4
# Use 1.10.188.42
# Fail
# Use 87.247.19.126
# Fail
# Use 95.165.244.46
# Fail
# Use 115.126.167.71
# Fail
# Use 139.59.215.181
# Fail
# Use 182.93.85.222
# Fail
# Use 189.14.193.242
# Fail
# Use 3.130.206.234
# Your IP address: 13.59.56.244
# Use 95.216.120.27
# Fail
# Use 200.35.49.89
# Fail
# Use 36.89.27.235
# Fail
# Use 91.139.1.158
# Fail
# Use 177.37.240.52
# Fail
# Use 101.109.11.26
# Fail
# Use 191.98.184.122
# Fail
# Use 95.80.252.189
# Fail
# Use 158.255.23.146
# Fail
# Use 187.188.213.4
# Fail
# Use 185.34.22.225
# Fail
# Use 193.29.59.122
# Fail
# Use 186.42.175.138
# Fail
# Use 194.35.115.4
# Fail
# Use 93.87.17.1
# Fail
# Use 79.115.245.227
# Fail
# Use 46.235.71.241
# Fail
# Use 95.104.54.227
# Fail
# Use 194.26.180.142
# Your IP address: 194.26.180.142
# Use 154.211.13.171
# Fail
# Use 103.126.149.98
# Fail
# Use 177.131.22.186
# Fail
# Use 182.53.197.202
# Fail
# Use 1.20.101.149
# Fail
# Use 147.78.160.10
# Fail
# Use 36.66.61.155
# Fail
# Use 36.66.61.155
# Fail
# Use 177.42.178.146
# Fail
# Use 1.10.188.42
# Fail
# Use 188.235.8.5
# Fail
# Use 102.176.160.70
# Fail
# Use 103.216.82.44
# Fail
# Use 114.29.236.225
# Fail
# Use 118.173.233.31
# Fail
# Use 103.197.48.98
# Fail
# Use 31.41.92.154
# Fail
# Use 94.205.140.158
# Fail
# Use 95.47.234.1
# Fail
# Use 171.97.80.65
# Fail
# Use 165.22.250.149
# Fail
# Use 3.130.206.234
# Your IP address: 18.217.194.217
# Use 94.230.158.37
# Fail
# Use 169.57.157.146
# Fail
# Use 191.103.219.225
# Fail
# Use 37.57.15.43
# Fail
# Use 171.97.80.65
# Fail
# Use 124.219.176.139
# Fail
# Use 178.155.104.84
# Fail
# Use 179.189.225.58
# Fail
# Use 1.4.198.206
# Fail
# Use 194.226.63.164
# Fail
# Use 124.122.100.233
# Fail
# Use 114.5.195.226
# Fail
# Use 202.166.196.28
# Fail
# Use 102.176.160.70
# Fail
# Use 115.126.167.71
# Fail
# Use 194.226.63.164
# Fail
# Use 187.188.213.4
# Fail
# Use 181.191.180.110
# Fail
# Use 45.234.200.18
# Fail
# Use 1.10.188.42
# Fail
# Use 45.235.87.65
# Fail
# Use 1.20.97.122
# Fail
# Use 79.104.25.218
# Fail
# Use 138.97.12.150
# Fail
# Use 118.173.233.150
# Fail
# Use 194.26.180.142
# Fail
# Use 177.46.147.89
# Fail
# Use 187.44.167.78
# Fail
# Use 79.115.245.227
# Fail
# Use 85.132.66.210
# Fail
# Use 85.10.219.100
# Fail
# Use 190.242.41.133
# Fail
# Use 110.74.195.215
# Fail
# Use 165.16.3.153
# Fail
# Use 68.183.45.111
# Fail
# Use 5.160.72.148
# Fail
# Use 103.209.178.208
# Fail
# Use 118.173.233.31
# Fail
# Use 118.97.235.234
# Fail
# Use 91.135.148.198
# Fail
# Use 178.93.23.146
# Fail
# Use 85.132.66.210
# Fail
# Use 128.199.90.230
# Fail
# Use 80.65.28.57
# Fail
# Use 68.183.45.111
# Fail
# Use 95.165.244.46
# Fail
# Use 95.104.54.227
# Fail
# Use 103.213.236.11
# Fail
# Use 103.130.114.122
# Fail
# Use 181.191.180.110
# Fail
# Use 36.74.47.4
# Your IP address: 36.74.47.4
# Use 95.165.244.46
# Fail
# Use 169.57.157.146
# Fail
# Use 36.37.73.245
# Fail
# Use 95.78.174.219
# Fail
# Use 104.171.124.90
# Fail
# Use 182.52.90.42
# Fail
# Use 134.209.184.20
# Fail
# Use 103.78.213.226
# Fail
# Use 46.246.14.6
# Fail
# Use 189.14.193.242
# Fail
# Use 191.98.184.122
# Fail
# Use 124.158.177.171
# Fail
# Use 200.186.53.98
# Fail
# Use 110.74.195.215
# Fail
# Use 5.9.218.107
# Fail
# Use 94.230.158.37
# Fail
# Use 110.74.222.106
# Fail
# Use 177.131.22.186
# Fail
# Use 103.126.149.98
# Fail
# Use 189.90.254.147
# Fail
# Use 179.27.83.222
# Fail
# Use 1.179.148.9
# Fail
# Use 118.175.226.30
# Fail
# Use 61.9.82.34
# Fail
# Use 185.99.64.75
# Fail
# Use 178.150.97.102
# Fail
# Use 95.170.208.42
# Fail
# Use 14.98.195.90
# Fail
# Use 188.235.8.5
# Fail
# Use 103.102.139.186
# Fail
# Use 178.93.23.146
# Fail
# Use 165.16.3.153
# Fail
# Use 82.137.250.145
# Your IP address: 82.137.250.145
# Use 36.75.212.60
# Your IP address: 36.75.212.60
# Use 95.170.208.42
# Fail
# Use 185.54.237.114
# Fail
# Use 176.98.76.203
# Fail
# Use 103.130.114.122
# Fail
# Use 182.93.85.222
# Fail
# Use 77.104.69.203
# Fail
# Use 142.93.122.175
# Fail
# Use 91.203.224.177
# Fail
# Use 193.193.240.34
# Fail
# Use 102.176.160.70
# Fail
# Use 139.5.71.70
# Fail
# Use 169.57.157.146
# Fail
# Use 102.176.160.70
# Fail
# Use 167.71.87.213
# Fail
# Use 3.130.206.234
# Your IP address: 52.15.42.36
# Use 195.182.22.178
# Fail
